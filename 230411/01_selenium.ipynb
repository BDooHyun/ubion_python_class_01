# %% [markdown]
# # selenium 라이브러리
# 1. 웹 어플리케이션 테스트를 위한 라이브러리
# 2. python에서 웹브라우져를 제어하는 기능
# 3. 웹드라이버를 별도 설치

# %%
# 라이브러리 설치
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\duja1\appdata\local\programs\python\python311\lib\site-packages (4.8.3)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\duja1\appdata\local\programs\python\python311\lib\site-packages (from selenium) (1.26.15)
# Requirement already satisfied: trio~=0.17 in c:\users\duja1\appdata\local\programs\python\python311\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\duja1\appdata\local\programs\python\python311\lib\site-packages (from selenium) (0.10.2)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\duja1\appdata\local\programs\python\python311\lib\site-packages (from selenium) (2022.12.7)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\duja1\appdata\roaming\python\python311\site-packages (from trio~=0.17->selenium) (22.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\duja1\appdata\local\programs\python\python311\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\duja1\appdata\local\programs\python\python311\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: idna in c:\users\duja1\appdata\roaming\python\python311\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\users\duja1\appdata\local\programs\python\python311\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in c:\users\duja1\appdata\roaming\python\python311\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\duja1\appdata\roaming\python\python311\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: exceptiongroup in c:\users\duja1\appdata\local\programs\python\python311\lib\site-packages (from trio-websocket~=0.9->selenium) (1.1.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\duja1\appdata\local\programs\python\python311\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\duja1\appdata\local\programs\python\python311\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\duja1\appdata\roaming\python\python311\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\duja1\appdata\local\programs\python\python311\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# [notice] A new release of pip available: 22.3.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# 라이브러리 로드
from selenium import webdriver

# %%
# 웹드라이버 파일의 위치 지정
path = "../chromedriver.exe"

# %%
# 웹드라이버 실행
driver = webdriver.Chrome(path)
# Out:
# C:\Users\duja1\AppData\Local\Temp\ipykernel_30676\1474807558.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)

# %%
# 웹 주소창에 값을 입력
driver.get("https://www.naver.com")

# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
# 검색어창 지정
element = driver.find_element(By.ID, "query")

# %%
# element에 입력할 값을 지정
element.send_keys("날씨")

# %%
element.send_keys(Keys.ENTER)

# %%
from bs4 import BeautifulSoup as bs

# %%
soup = bs(driver.page_source, "html.parser")

# %%
data = soup.find("ul", attrs = {
    "class" : "list_news"
})
data
# Out:
# <ul class="list_news"> <li class="bx" id="sp_nws_all1"> <div class="news_wrap api_ani_send"> <div class="news_area"> <div class="news_info"> <div class="api_save_group _keep_wrap"> <a aria-pressed="false" class="btn_save _keep_trigger" data-url="http://www.newsis.com/view/?id=NISX20230419_0002272005&amp;cID=10201&amp;pID=10200" href="#" onclick="tCR('a=nws_all*h.kep&amp;r=1&amp;i=88000127_000000000000000011811342&amp;u=javascript'); return false;" role="button"><i class="spnew ico_save">문서 저장하기</i></a> <div class="api_ly_save _keep_save_layer"> <a class="spnew_af item item_save _keep_save" data-cr-off="a=nws_all*h.kepoff&amp;r=1&amp;i=88000127_000000000000000011811342&amp;u=javascript" data-cr-on="a=nws_all*h.kepon&amp;r=1&amp;i=88000127_000000000000000011811342&amp;u=javascript" href="#" role="button">Keep에 저장</a> <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick="return goOtherCR(this,'a=nws_all*h.kephome&amp;r=1&amp;i=88000127_000000000000000011811342&amp;u='+urlencode(this.href));" target="_blank">Keep 바로가기</a> </div></div><div class="info_group"> <a class="info press" href="http://www.newsis.com" onclick="return goOtherCR(this, 'a=nws_all*h.prof&amp;r=1&amp;i=88000127_000000000000000011811342&amp;g=003.0011811342&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fmimgnews.pstatic.net%2Fimage%2Fupload%2Foffice_logo%2F003%2F2019%2F02%2F19%2Flogo_003_18_20190219111719.jpg&amp;type=f54_54&amp;expire=24&amp;refresh=true" data-obstatus="ob-once" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="..." width="20"/></span>뉴시스<i class="spnew ico_pick">언론사 선정</i></a><span class="info">1시간 전</span><a class="info" href="https://n.news.naver.com/mnews/article/003/0011811342?sid=102" onclick="return goOtherCR(this, 'a=nws_all*h.nav&amp;r=1&amp;i=88000127_000000000000000011811342&amp;u='+urlencode(this.href));" target="_blank">네이버뉴스</a> </div></div><a class="news_tit" href="http://www.newsis.com/view/?id=NISX20230419_0002272005&amp;cID=10201&amp;pID=10200" onclick="return goOtherCR(this, 'a=nws_all*h.tit&amp;r=1&amp;i=88000127_000000000000000011811342&amp;g=003.0011811342&amp;u='+urlencode(this.href));" target="_blank" title="'초여름' 날씨에 서울 낮 최고 28도…미세먼지 '좋음'">'초여름' <mark>날씨</mark>에 서울 낮 최고 28도…미세먼지 '좋음'</a> <div class="news_dsc"> <div class="dsc_wrap"> <a class="api_txt_lines dsc_txt_wrap" href="http://www.newsis.com/view/?id=NISX20230419_0002272005&amp;cID=10201&amp;pID=10200" onclick="return goOtherCR(this, 'a=nws_all*h.body&amp;r=1&amp;i=88000127_000000000000000011811342&amp;g=003.0011811342&amp;u='+urlencode(this.href));" target="_blank">기사내용 요약 오전 짙은 안개…낮 최고 17~29도 대전 28도, 광주 25도, 부산 19도 [서울=뉴시스]정진형 기자 = 19일 수요일은 중부지방을 비롯한 내륙의 낮 기온이 25도 이상으로 오르는 등 초여름 <mark>날씨</mark>가 이어지겠다....</a> </div></div></div><a class="dsc_thumb" href="http://www.newsis.com/view/?id=NISX20230419_0002272005&amp;cID=10201&amp;pID=10200" onclick="return goOtherCR(this, 'a=nws_all*h.img&amp;r=1&amp;i=88000127_000000000000000011811342&amp;g=003.0011811342&amp;u='+urlencode(this.href));" target="_blank"><img alt="‘초여름‘ 날씨에 서울" class="thumb api_get" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F003%2F2023%2F04%2F19%2F11811342.jpg&amp;type=ff264_180&amp;expire=2&amp;refresh=true" data-obstatus="ob-once" height="90" onerror="this.parentNode.style.display='none';" src="..." width="132"/></a> </div><div class="news_cluster"> <ul class="list_cluster"> <li class="sub_bx"> <span class="sub_wrap"> <span class="sub_area"> <cite class="sub_txt press" title="SBS">SBS</cite><span class="sub_txt">4시간 전</span><a class="sub_txt" href="https://n.news.naver.com/mnews/article/055/0001051546?sid=103" onclick="return goOtherCR(this, 'a=nws_all*c.nav&amp;r=2&amp;i=8800011C_000000000000000001051546&amp;u='+urlencode(this.href));" target="_blank">네이버뉴스</a> </span> ...

# %%
_list = data.find_all("a", attrs = {
    "class" : "news_tit"
})

# %%
result = []
for i in _list :
    result.append(i.get_text())
result
# Out:
# ["'초여름' 날씨에 서울 낮 최고 28도…미세먼지 '좋음'",
#  '[날씨] 한낮 초여름 기온…서울 최고 27도',
#  '[오늘날씨] 갑자기 온 여름…낮 최고 29도, 서울도 27도',
#  '[오늘의 날씨]전국이 초여름 날씨…서울 낮 최고 27도']

# %%
driver = webdriver.Chrome(path)
code = "005380"
driver.get("https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=" + code)
# Out:
# C:\Users\duja1\AppData\Local\Temp\ipykernel_30676\1927452036.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)

# %%
element = driver.find_element(By.CLASS_NAME, "menu")
print(element)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="3d40434cc9b076992ea3e26e96fe7a27", element="c0d9ab3e-c339-4824-a884-1c7626132318")>

# %%
element2 = element.find_elements(By.TAG_NAME, "a")[3]
element2.click()

# %%
soup = bs(driver.page_source, "html.parser")

# %%
data = soup.find_all("table", attrs = {
    "class" : "gHead01 all-width data-list"
})[1]

# %%
# 컬럼 부분에 들어갈 값을 추출
_list = data.find_all("th")

# %%
col_list = []
for i in _list :
    col_list.append(i.get_text())

col_list
# Out:
# ['항목',
#  '\n2018/12(IFRS연결)\n',
#  '\n2019/12(IFRS연결)\n',
#  '\n2020/12(IFRS연결)\n',
#  '\n2021/12(IFRS연결)\n',
#  '\n2022/12(IFRS연결)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t연간컨센서스보기\n\n',
#  '\n2023/12(E)(IFRS연결)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t연간컨센서스닫기\n\n',
#  '\n전년대비(YoY)\n',
#  '\n전년대비(YoY)\n']

# %%
# value 값을 추출
data2 = data.find("tbody")

# %%
data3 = data2.find_all("tr")
data3
# Out:
# [<tr class="lvl1" data-pacc="">
#  <td class="txt" title="EPS">
#  <span class="cut">
#  <a class="btn_moreE" data-acc="312000"><span class="icon-sprite icon-moreE">펼치기</span></a>
#
#  												EPS
#  													</span>
#  </td>
#  <td class="num ext0">5,352</td>
#  <td class="num ext1">10,761</td>
#  <td class="num ext2">5,143</td>
#  <td class="num ext3">17,846</td>
#  <td class="num ext4">26,592</td>
#  <td class="num ext5">32,840</td>
#  <td class="num ext6 noline-right">49</td>
#  <td class="num ext7 noline-right">24</td>
#  </tr>,
#  <tr class="lvl1" data-pacc="312000" style="display: none;">
#  <td class="txt" title="당기순이익(지배)＜당기＞">
#  <span class="cut">
#  <span style="width: 12px; display: inline-block"> </span>
#
#  												당기순이익(지배)＜당기＞
#  													</span>
#  </td>
#  <td class="num ext0">15,080.8</td>
#  <td class="num ext1">29,800.5</td>
#  <td class="num ext2">14,244.4</td>
#  <td class="num ext3">49,423.6</td>
#  <td class="num ext4">73,643.6</td>
#  <td class="num ext5">90,120.9</td>
#  <td class="num ext6 noline-right"> </td>
#  <td class="num ext7 noline-right"> </td>
#  </tr>,
#  <tr class="lvl1" data-pacc="312000" style="display: none;">
#  <td class="txt" title="보통주수정평균발행주식수＜당기＞">
#  <span class="cut">
#  <span style="width: 12px; display: inline-block"> </span>
#
#  												보통주수정평균발행주식수＜당기＞
#  													</span>
#  </td>
#  <td class="num ext0">217,415,903</td>
#  <td class="num ext1">213,668,187</td>
#  <td class="num ext2">213,668,187</td>
#  <td class="num ext3">213,668,187</td>
#  <td class="num ext4">213,668,187</td>
#  <td class="num ext5">211,724,685</td>
#  <td class="num ext6 noline-right"> </td>
#  <td class="num ext7 noline-right"> </td>
#  </tr>,
#  <tr class="lvl1" data-pacc="312000" style="display: none;">
#  <td class="txt" title="우선주수정평균발행주식수＜당기＞">
#  <span class="cut">
#  <span style="width: 12px; display: inline-block"> </span>
#
#  												우선주수정평균발행주식수＜당기＞
#  													</span>
#  </td>
#  <td class="num ext0">64,366,142</td>
#  <td class="num ext1">63,270,871</td>
#  <td class="num ext2">63,270,871</td>
#  <td class="num ext3">63,270,871</td>
#  <td class="num ext4">63,270,871</td>
#  <td class="num ext5">62,695,368</td>
#  <td class="num ext6 noline-right"> </td>
#  <td class="num ext7 noline-right"> </td>
#  </tr>,
#  <tr class="lvl1" data-pacc="">
#  <td class="txt" title="BPS">
#  <span class="cut">
#  <a class="btn_moreE" data-acc="314000"><span class="icon-sprite icon-moreE">펼치기</span></a>
#
#  												BPS
#  													</span>
#  </td>
#  <td class="num ext0">256,422</td>
#  <td class="num ext1">267,549</td>
#  <td class="num ext2">266,968</td>
#  <td class="num ext3">289,609</td>
#  <td class="num ext4">315,142</td>
#  <td class="num ext5">345,387</td>
#  <td class="num ext6 noline-right">9</td>
#  <td class="num ext7 noline-right">10</td>
#  </tr>,
#  <tr class="lvl1" data-pacc="314000" style="display: none;">
#  <td class="txt" title="자본총계(지배)＜당기＞">
#  <span class="cut">
#  <span style="width: 12px; display: inline-block"> </span>
#
#  												자본총계(지배)＜당기＞
#  													</span>
#  </td>
#  <td class="num ext0">679,739.7</td>
#  <td class="num ext1">700,658.0</td>
#  <td class="num ext2">694,806.3</td>
#  <td class="num ext3">749,861.2</td>
#  <td class="num ext4">823,492.9</td>
#  <td class="num ext5">904,637.8</td>
#  <td class="num ext6 noline-right"> </td>
#  <td class="num ext7 noline-right"> </td>
#  </tr>,
#  <tr class="lvl1" data-pacc="314000" style="display: none;">
#  <td class="txt" title="보통주수정기말발행주식수(자사주차감)＜당기＞">
#  <span class="cut">
#  <span style="width: 12px; display: inline-block"> </span>
#
#  												보통주수정기말발행주식수(자사주차감)＜당기＞
#  													</span>
#  </td>
#  <td class="num ext0">204,280,606</td>
#  <td class="num ext1">201,833,036</td>
#  <td class="num ext2">200,576,769</td>
#  <td class="num ext3">199,619,945</td>
#  <td class="num ext4">202,259,476</td>
#  <td class="num ext5">202,870,846</td>
#  <td class="num ext6 noline-right"> </td>
#  <td class="num ext7 noline-right"> </td>
#  </tr>,
#  <tr class="lvl1" data-pacc="314000" style="display: none;">
#  <td class="txt" title="우선주수정기말발행주식수(자사주차감)＜당기＞">
#  <span class="cut">
#  <span style="width: 12px; display: inline-block"> </span>
#
#  												우선주수정기말발행주식수(자사주차감)＜당기＞
#  													</span>
#  </td>
#  <td class="num ext0">60,805,434</td>
#  <td class="num ext1">60,047,227</td>
#  <td class="num ext2">59,681,734</td>
#  <td class="num ext3">59,302,110</td>
#  <td class="num ext4">59,049,027</td>
#  <td class="num ext5">59,049,027</td>
#  <td class="num ext6 noline-right"> </td>
#  <td class="num ext7 noline-right"> </td>
#  </tr>,
#  <tr class="lvl1" data-pacc="">
#  <td class="txt" title="CPS">
#  <span class="cut">
#  <a class="btn_moreE" data-acc="316000"><span class="icon-sprite icon-moreE">펼치기</span></a>
#
#  												CPS
#  													</span>
#  </td>
#  <td class="num ext0">13,359</td>
#  <td class="num ext1">1,516</td>
#  <td class="num ext2 cUp">-1,480</td>
#  <td class="num ext3 cUp">-4,248</td>
#  <td class="num ext4">38,374</td>
#  <td class="num ext5">54,071</td>
#  <td class="num ext6 noline-right">1,003</td>
#  <td class="num ext7 noline-right">41</td>
#  </tr>,
#  <tr class="lvl1" data-pacc="316000" style="display: none;">
#  <td class="txt" title="영업활동현금흐름＜당기＞">
#  <span class="cut">
#  <span style="width: 12px; display: inline-block"> </span>
#
#  												영업활동현금흐름＜당기＞
#  													</span>
#  </td>
#  <td class="num ext0">37,642.7</td>
#  <td class="num ext1">4,197.8</td>
#  <td class="num ext2 cUp">-4,098.1</td>
#  <td class="num ext3 cUp">-11,764.2</td>
#  <td class="num ext4">106,273.1</td>
#  <td class="num ext5">140,233.2</td>
#  <td class="num ext6 noline-right"> </td>
#  <td class="num ext7 noline-right"> </td>
#  </tr>,
#  <tr class="lvl1" data-pacc="316000" style="display: none;">
#  <td class="txt" title="보통주수정평균발행주식수＜당기＞">
#  <span class="cut">
#  <span style="width: 12px; display: inline-block"> </span>
#
#  												보통주수정평균발행주식수＜당기＞
#  													</span>
#  </td>
#  <td class="num ext0">217,415,903</td>
#  <td class="num ext1">213,668,187</td>
#  <td class="num ext2">213,668,187</td>
#  <td class="num ext3">213,668,187</td>
#  <td class="num ext4">213,668,187</td>
#  <td class="num ext5">211,724,685</td>
#  <td class="num ext6 noline-right"> </td>
#  <td class="num ext7 noline-right"> </td>
#  </tr>,
#  <tr class="lvl1" data-pacc="316000" style="display: none;">
#  <td class="txt" title="우선주수정평균발행주식수＜당기＞">
#  <span class="cut">
#  <span style="width: 12px; display: inline-block"> </span>
#
#  												우선주수정평균발행주식수＜당기＞
#  													</span>
#  </td>
#  <td class="num ext0">64,366,142</td>
#  <td class="num ext1">63,270,871</td>
#  <td class="num ext2">63,270,871</td>
#  <td class="num ext3">63,270,871</td>
#  <td class="num ext4">63,270,871</td>
#  <td class="num ext5">62,695,368</td>
#  <td class="num ext6 noline-right"> </td>
#  <td class="num ext7 noline-right"> </td>
#  </tr>,
#  <tr class="lvl1" data-pacc="">
#  <td class="txt" title="SPS">
#  <span class="cut">
#  <a class="btn_moreE" data-acc="318000"><span class="icon-sprite icon-moreE">펼치기</span></a>
#
#  												SPS
#  													</span>
#  </td>
#  <td class="num ext0">343,573</td>
#  <td class="num ext1">381,840</td>
#  <td class="num ext2">375,525</td>
#  <td class="num ext3">424,681</td>
#  <td class="num ext4">514,653</td>
#  <td class="num ext5">554,958</td>
#  <td class="num ext6 noline-right">21</td>
#  <td class="num ext7 noline-right">8</td>
#  </tr>,
#  <tr class="lvl1" data-pacc="318000" style="display: none;">
#  <td class="txt" title="매출액＜당기＞">
#  <span class="cut">
#  <span style="width: 12px; display: inline-block"> </span>
#
#  												매출액＜당기＞
#  													</span>
#  </td>
#  <td class="num ext0">968,126.1</td>
#  <td class="num ext1">1,057,464.2</td>
#  <td class="num ext2">1,039,976.0</td>
#  <td class="num ext3">1,176,106.3</td>
#  <td class="num ext4">1,425,275.4</td>
#  <td class="num ext5">1,522,915.8</td>
#  <td class="num ext6 noline-right"> </td>
#  <td class="num ext7 noline-right"> </td>
#  </tr>,
#  <tr class="lvl1" data-pacc="318000" style="display: none;">
#  <td class="txt" title="보통주수정평균발행주식수＜당기＞">
#  <span class="cut">
#  <span style="width: 12px; display: inline-block"> </span>
#
#  												보통주수정평균발행주식수＜당기＞
#  													</span>
#  </td>
#  <td class="num ext0">217,415,903</td>
#  <td class="num ext1">213,668,187</td>
#  <td class="num ext2">213,668,187</td>
#  <td class="num ext3">213,668,187</td>
#  <td class="num ext4">213,668,187</td>
#  <td class="num ext5">211,724,685</td>
#  <td class="num ext6 noline-right"> </td>
#  <td class="num ext7 noline-right"> </td>
#  </tr>,
#  <tr class="lvl1" data-pacc="318000" style="display: none;">
#  <td class="txt" title="우선주수정평균발행주식수＜당기＞">
#  <span class="cut">
#  <span style="width: 12px; display: inline-block"> </span>
#
#  												우선주수정평균발행주식수＜당기＞
#  													</span>
#  </td>
#  <td class="num ext0">64,366,142</td>
#  <td class="num ext1">63,270,871</td>
#  <td class="num ext2">63,270,871</td>
#  <td class="num ext3">63,270,871</td>
#  <td class="num ext4">63,270,871</td>
#  <td class="num ext5">62,695,368</td>
#  <td class="num ext6 noline-right"> </td>
#  <td class="num ext7 noline-right"> </td>
#  </tr>,
#  <tr class="lvl1" data-pacc="">
#  <td class="txt" title="PER">
#  <span class="cut">
#  <a class="btn_moreE" data-acc="382100"><span class="icon-sprite icon-moreE">펼치기</span></a>
#
#  												PER
#  													</span>
#  </td>
#  <td class="num ext0">22.14</td>
#  <td class="num ext1">11.20</td>
#  <td class="num ext2">37.33</td>
#  <td class="num ext3">11.71</td>
#  <td class="num ext4">5.68</td>
#  <td class="num ext5">5.83</td>
#  <td class="num ext6 noline-right cUp">-51.51</td>
#  <td class="num ext7 noline-right">2.64</td>
#  </tr>,
#  <tr class="lvl1" data-pacc="382100" style="display: none;">
#  <td class="txt" title="보통주수정주가(기말)＜당기＞">
#  <span class="cut">
#  <span style="width: 12px; display: inline-block"> </span>
#
#  												보통주수정주가(기말)＜당기＞
#  													</span>
#  </td>
#  <td class="num ext0">118,500</td>
#  <td class="num ext1">120,500</td>
#  <td class="num ext2">192,000</td>
#  <td class="num ext3">209,000</td>
#  <td class="num ext4">151,000</td>
#  <td class="num ext5">191,400</td>
#  <td class="num ext6 noline-right"> </td>
#  <td class="num ext7 noline-right"> </td>
#  </tr>,
#  <tr class="lvl1" data-pacc="382100" style="display: none;">
#  <td class="txt" title="EPS＜당기＞">
#  <span class="cut">
#  <span style="width: 12px; display: inline-block"> </span>
#
#  												EPS＜당기＞
#  													</span>
#  </td>
#  <td class="num ext0">5,352</td>
#  <td class="num ext1">10,761</td>
#  <td class="num ext2">5,143</td>
#  <td class="num ext3">17,846</td>
#  <td class="num ext4">26,592</td>
#  <td class="num ext5">32,840</td>
#  <td class="num ext6 noline-right"> </td>
#  <td class="num ext7 noline-right"> </td>
#  </tr>,
#  <tr class="lvl1" data-pacc="">
#  <td class="txt" title="PBR">
#  <span class="cut">
#  <a class="btn_moreE" data-acc="382500"><span class="icon-sprite icon-moreE">펼치기</span></a>
#
#  												PBR
#  													</span>
#  </td>
#  <td class="num ext0">0.46</td>
#  <td class="num ext1">0.45</td>
#  <td class="num ext2">0.72</td>
#  <td class="num ext3">0.72</td>
#  <td class="num ext4">0.48</td>
#  <td class="num ext5">0.55</td>
#  <td class="num ext6 noline-right cUp">-33.60</td>
#  <td class="num ext7 noline-right">15.65</td>
#  </tr>,
#  <tr class="lvl1" data-pacc="382500" style="display: none;">
#  <td class="txt" title="보통주수정주가(기말)＜당기＞">
#  <span class="cut">
#  <span style="width: 12px; display: inline-block"> </span>
#
#  												보통주수정주가(기말)＜당기＞
#  													</span>
#  </td>
#  <td class="num ext0">118,500</td>
#  <td class="num ext1">120,500</td>
#  <td class="num ext2">192,000</td>
#  <td class="num ext3">209,000</td>
#  <td class="num ext4">151,000</td>
#  <td class="num ext5">191,400</td>
#  <td class="num ext6 noline-right"> </td>
#  <td class="num ext7 noline-right"> </td>
#  </tr>,
#  <tr class="lvl1" data-pacc="382500" style="display: none;">
#  <td class="txt" title="BPS＜당기＞">
#  <span class="cut">
#  <span style="width: 12px; display: inline-block"> </span>
#
#  												BPS＜당기＞
#  													</span>
#  </td>
#  <td class="num ext0">256,422</td>
#  <td class="num ext1">267,549</td>
#  <td class="num ext2">266,968</td>
#  <td class="num ext3">289,609</td>
#  <td class="num ext4">315,142</td>
#  <td class="num ext5">345,387</td>
#  <td class="num ext6 noline-right"> </td>
#  <td class="num ext7 noline-right"> </td>
#  </tr>,
#  <tr class="lvl1" data-pacc="">
#  <td class="txt" title="PCR">
#  <span class="cut">
#  <a class="btn_moreE" data-acc="382900"><span class="icon-sprite icon-moreE">펼치기</span></a>
#
#  												PCR
#  													</span>
#  </td>
#  <td class="num ext0">8.87</td>
#  <td class="num ext1">79.50</td>
#  <td class="num ext2 cUp">-129.75</td>
#  <td class="num ext3 cUp">-49.20</td>
#  <td class="num ext4">3.93</td>
#  <td class="num ext5">3.54</td>
#  <td class="num ext6 noline-right">108.00</td>
#  <td class="num ext7 noline-right cUp">-10.04</td>
#  </tr>,
#  <tr class="lvl1" data-pacc="382900" style="display: none;">
#  <td class="txt" title="보통주수정주가(기말)＜당기＞">
#  <span class="cut">
#  <span style="width: 12px; display: inline-block"> </span>
#
#  												보통주수정주가(기말)＜당기＞
#  													</span>
#  </td>
#  <td class="num ext0">118,500</td>
#  <td class="num ext1">120,500</td>
#  <td class="num ext2">192,000</td>
#  <td class="num ext3">209,000</td>
#  <td class="num ext4">151,000</td>
#  <td class="num ext5">191,400</td>
#  <td class="num ext6 noline-right"> </td>
#  <td class="num ext7 noline-right"> </td>
#  </tr>,
#  <tr class="lvl1" data-pacc="382900" style="display: none;">
#  <td class="txt" title="CPS＜당기＞">
#  <span class="cut">
#  <span style="width: 12px; display: inline-block"> </span>
#
#  												CPS＜당기＞
#  													</span>
#  </td>
#  <td class="num ext0">13,359</td>
#  <td class="num ext1">1,516</td>
#  <td class="num ext2 cUp">-1,480</td>
#  <td class="num ext3 cUp">-4,248</td>
#  <td class="num ext4">38,374</td>
#  <td class="num ext5">54,071</td>
#  <td class="num ext6 noline-right"> </td>
#  <td class="num ext7 noline-right"> </td>
#  </tr>,
#  <tr class="lvl1" data-pacc="">
#  <td class="txt" title="PSR">
#  <span class="cut">
#  <a class="btn_moreE" data-acc="383300"><span class="icon-sprite icon-moreE">펼치기</span></a>
#
#  												PSR
#  													</span>
#  </td>
#  <td class="num ext0">0.34</td>
#  <td class="num ext1">0.32</td>
#  <td class="num ext2">0.51</td>
#  <td class="num ext3">0.49</td>
#  <td class="num ext4">0.29</td>
#  <td class="num ext5">0.34</td>
#  <td class="num ext6 noline-right cUp">-40.38</td>
#  <td class="num ext7 noline-right">17.55</td>
#  </tr>,
#  <tr class="lvl1" data-pacc="383300" style="display: none;">
#  <td class="txt" title="보통주수정주가(기말)＜당기＞">
#  <span class="cut">
#  <span style="width: 12px; display: inline-block"> </span>
#
#  												보통주수정주가(기말)＜당기＞
#  													</span>
#  </td>
#  <td class="num ext0">118,500</td>
#  <td class="num ext1">120,500</td>
#  <td class="num ext2">192,000</td>
#  <td class="num ext3">209,000</td>
#  <td class="num ext4">151,000</td>
#  <td class="num ext5">191,400</td>
#  <td class="num ext6 noline-right"> </td>
#  <td class="num ext7 noline-right"> </td>
#  </tr>,
#  <tr class="lvl1" data-pacc="383300" style="display: none;">
#  <td class="txt" title="SPS＜당기＞">
#  <span class="cut">
#  <span style="width: 12px; display: inline-block"> </span>
#
#  												SPS＜당기＞
#  													</span>
#  </td>
#  <td class="num ext0">343,573</td>
#  <td class="num ext1">381,840</td>
#  <td class="num ext2">375,525</td>
#  <td class="num ext3">424,681</td>
#  <td class="num ext4">514,653</td>
#  <td class="num ext5">554,958</td>
#  <td class="num ext6 noline-right"> </td>
#  <td class="num ext7 noline-right"> </td>
#  </tr>,
#  <tr class="lvl1" data-pacc="">
#  <td class="txt" title="EV/EBITDA">
#  <span class="cut">
#  <a class="btn_moreE" data-acc="331000"><span class="icon-sprite icon-moreE">펼치기</span></a>
#
#  												EV/EBITDA
#  													</span>
#  </td>
#  <td class="num ext0">12.37</td>
#  <td class="num ext1">11.75</td>
#  <td class="num ext2">16.57</td>
#  <td class="num ext3">11.37</td>
#  <td class="num ext4">7.96</td>
#  <td class="num ext5">7.79</td>
#  <td class="num ext6 noline-right cUp">-30.00</td>
#  <td class="num ext7 noline-right cUp">-2.08</td>
#  </tr>,
#  <tr class="lvl1" data-pacc="331000" style="display: none;">
#  <td class="txt" title="EV＜당기＞">
#  <span class="cut">
#  <span style="width: 12px; display: inline-block"> </span>
#
#  												EV＜당기＞
#  													</span>
#  </td>
#  <td class="num ext0">765,044.6</td>
#  <td class="num ext1">873,635.9</td>
#  <td class="num ext2">1,090,036.7</td>
#  <td class="num ext3">1,277,281.6</td>
#  <td class="num ext4">1,183,246.9</td>
#  <td class="num ext5">1,285,322.1</td>
#  <td class="num ext6 noline-right"> </td>
#  <td class="num ext7 noline-right"> </td>
#  </tr>,
#  <tr class="lvl1" data-pacc="331000" style="display: none;">
#  <td class="txt" title="EBITDA＜당기＞">
#  <span class="cut">
#  <span style="width: 12px; display: inline-block"> </span>
#
#  												EBITDA＜당기＞
#  													</span>
#  </td>
#  <td class="num ext0">61,836.3</td>
#  <td class="num ext1">74,373.8</td>
#  <td class="num ext2">65,800.4</td>
#  <td class="num ext3">112,346.9</td>
#  <td class="num ext4">148,673.9</td>
#  <td class="num ext5">164,923.4</td>
#  <td class="num ext6 noline-right"> </td>
#  <td class="num ext7 noline-right"> </td>
#  </tr>,
#  <tr class="lvl1" data-pacc="">
#  <td class="txt" title="DPS">
#  <span class="cut">
#  <a class="btn_moreE" data-acc="423800"><span class="icon-sprite icon-moreE">펼치기</span></a>
#
#  												DPS
#  													</span>
#  </td>
#  <td class="num ext0">4,000</td>
#  <td class="num ext1">4,000</td>
#  <td class="num ext2">3,000</td>
#  <td class="num ext3">5,000</td>
#  <td class="num ext4">7,000</td>
#  <td class="num ext5"></td>
#  <td class="num ext6 noline-right">40</td>
#  <td class="num ext7 noline-right"> </td>
#  </tr>,
#  <tr class="lvl1" data-pacc="423800" style="display: none;">
#  <td class="txt" title="현금DPS">
#  <span class="cut">
#  <span style="width: 12px; display: inline-block"> </span>
#
#  												현금DPS
#  													</span>
#  </td>
#  <td class="num ext0">4,000</td>
#  <td class="num ext1">4,000</td>
#  <td class="num ext2">3,000</td>
#  <td class="num ext3">5,000</td>
#  <td class="num ext4">7,000</td>
#  <td class="num ext5"></td>
#  <td class="num ext6 noline-right"> </td>
#  <td class="num ext7 noline-right"> </td>
#  </tr>,
#  <tr class="lvl1" data-pacc="423800" style="display: none;">
#  <td class="txt" title="주식DPS">
#  <span class="cut">
#  <span style="width: 12px; display: inline-block"> </span>
#
#  												주식DPS
#  													</span>
#  </td>
#  <td class="num ext0">0</td>
#  <td class="num ext1">0</td>
#  <td class="num ext2">0</td>
#  <td class="num ext3">0</td>
#  <td class="num ext4"></td>
#  <td class="num ext5"></td>
#  <td class="num ext6 noline-right"> </td>
#  <td class="num ext7 noline-right"> </td>
#  </tr>,
#  <tr class="lvl1" data-pacc="">
#  <td class="txt" title="현금배당수익률">
#  <span class="cut">
#  <span style="width: 12px; display: inline-block"> </span>
#
#  												현금배당수익률
#  													</span>
#  </td>
#  <td class="num ext0">3.38</td>
#  <td class="num ext1">3.32</td>
#  <td class="num ext2">1.56</td>
#  <td class="num ext3">2.39</td>
#  <td class="num ext4">4.64</td>
#  <td class="num ext5">3.74</td>
#  <td class="num ext6 noline-right">2.24</td>
#  <td class="num ext7 noline-right cUp">-0.90</td>
#  </tr>,
#  <tr class="lvl1" data-pacc="">
#  <td class="txt" title="현금배당성향(%)">
#  <span class="cut">
#  <span style="width: 12px; display: inline-block"> </span>
#
#  												현금배당성향(%)
#  													</span>
#  </td>
#  <td class="num ext0">70.70</td>
#  <td class="num ext1">35.35</td>
#  <td class="num ext2">55.15</td>
#  <td class="num ext3">26.32</td>
#  <td class="num ext4">24.85</td>
#  <td class="num ext5">16.78</td>
#  <td class="num ext6 noline-right cUp">-1.46</td>
#  <td class="num ext7 noline-right cUp">-8.07</td>
#  </tr>]

# %%
value_list = []

for i in data3 :
    sample_list = []
    _list = i.find_all("td")
    for j in _list :
        sample_list.append(j.get_text())
    value_list.append(sample_list)

value_list
# Out:
# [['\n\n펼치기\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tEPS\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '5,352',
#   '10,761',
#   '5,143',
#   '17,846',
#   '26,592',
#   '32,840',
#   '49',
#   '24'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t당기순이익(지배)＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '15,080.8',
#   '29,800.5',
#   '14,244.4',
#   '49,423.6',
#   '73,643.6',
#   '90,120.9',
#   '\xa0',
#   '\xa0'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t보통주수정평균발행주식수＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '217,415,903',
#   '213,668,187',
#   '213,668,187',
#   '213,668,187',
#   '213,668,187',
#   '211,724,685',
#   '\xa0',
#   '\xa0'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t우선주수정평균발행주식수＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '64,366,142',
#   '63,270,871',
#   '63,270,871',
#   '63,270,871',
#   '63,270,871',
#   '62,695,368',
#   '\xa0',
#   '\xa0'],
#  ['\n\n펼치기\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tBPS\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '256,422',
#   '267,549',
#   '266,968',
#   '289,609',
#   '315,142',
#   '345,387',
#   '9',
#   '10'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t자본총계(지배)＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '679,739.7',
#   '700,658.0',
#   '694,806.3',
#   '749,861.2',
#   '823,492.9',
#   '904,637.8',
#   '\xa0',
#   '\xa0'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t보통주수정기말발행주식수(자사주차감)＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '204,280,606',
#   '201,833,036',
#   '200,576,769',
#   '199,619,945',
#   '202,259,476',
#   '202,870,846',
#   '\xa0',
#   '\xa0'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t우선주수정기말발행주식수(자사주차감)＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '60,805,434',
#   '60,047,227',
#   '59,681,734',
#   '59,302,110',
#   '59,049,027',
#   '59,049,027',
#   '\xa0',
#   '\xa0'],
#  ['\n\n펼치기\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tCPS\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '13,359',
#   '1,516',
#   '-1,480',
#   '-4,248',
#   '38,374',
#   '54,071',
#   '1,003',
#   '41'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t영업활동현금흐름＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '37,642.7',
#   '4,197.8',
#   '-4,098.1',
#   '-11,764.2',
#   '106,273.1',
#   '140,233.2',
#   '\xa0',
#   '\xa0'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t보통주수정평균발행주식수＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '217,415,903',
#   '213,668,187',
#   '213,668,187',
#   '213,668,187',
#   '213,668,187',
#   '211,724,685',
#   '\xa0',
#   '\xa0'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t우선주수정평균발행주식수＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '64,366,142',
#   '63,270,871',
#   '63,270,871',
#   '63,270,871',
#   '63,270,871',
#   '62,695,368',
#   '\xa0',
#   '\xa0'],
#  ['\n\n펼치기\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tSPS\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '343,573',
#   '381,840',
#   '375,525',
#   '424,681',
#   '514,653',
#   '554,958',
#   '21',
#   '8'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t매출액＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '968,126.1',
#   '1,057,464.2',
#   '1,039,976.0',
#   '1,176,106.3',
#   '1,425,275.4',
#   '1,522,915.8',
#   '\xa0',
#   '\xa0'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t보통주수정평균발행주식수＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '217,415,903',
#   '213,668,187',
#   '213,668,187',
#   '213,668,187',
#   '213,668,187',
#   '211,724,685',
#   '\xa0',
#   '\xa0'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t우선주수정평균발행주식수＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '64,366,142',
#   '63,270,871',
#   '63,270,871',
#   '63,270,871',
#   '63,270,871',
#   '62,695,368',
#   '\xa0',
#   '\xa0'],
#  ['\n\n펼치기\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tPER\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '22.14',
#   '11.20',
#   '37.33',
#   '11.71',
#   '5.68',
#   '5.83',
#   '-51.51',
#   '2.64'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t보통주수정주가(기말)＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '118,500',
#   '120,500',
#   '192,000',
#   '209,000',
#   '151,000',
#   '191,400',
#   '\xa0',
#   '\xa0'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tEPS＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '5,352',
#   '10,761',
#   '5,143',
#   '17,846',
#   '26,592',
#   '32,840',
#   '\xa0',
#   '\xa0'],
#  ['\n\n펼치기\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tPBR\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '0.46',
#   '0.45',
#   '0.72',
#   '0.72',
#   '0.48',
#   '0.55',
#   '-33.60',
#   '15.65'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t보통주수정주가(기말)＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '118,500',
#   '120,500',
#   '192,000',
#   '209,000',
#   '151,000',
#   '191,400',
#   '\xa0',
#   '\xa0'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tBPS＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '256,422',
#   '267,549',
#   '266,968',
#   '289,609',
#   '315,142',
#   '345,387',
#   '\xa0',
#   '\xa0'],
#  ['\n\n펼치기\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tPCR\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '8.87',
#   '79.50',
#   '-129.75',
#   '-49.20',
#   '3.93',
#   '3.54',
#   '108.00',
#   '-10.04'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t보통주수정주가(기말)＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '118,500',
#   '120,500',
#   '192,000',
#   '209,000',
#   '151,000',
#   '191,400',
#   '\xa0',
#   '\xa0'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tCPS＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '13,359',
#   '1,516',
#   '-1,480',
#   '-4,248',
#   '38,374',
#   '54,071',
#   '\xa0',
#   '\xa0'],
#  ['\n\n펼치기\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tPSR\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '0.34',
#   '0.32',
#   '0.51',
#   '0.49',
#   '0.29',
#   '0.34',
#   '-40.38',
#   '17.55'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t보통주수정주가(기말)＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '118,500',
#   '120,500',
#   '192,000',
#   '209,000',
#   '151,000',
#   '191,400',
#   '\xa0',
#   '\xa0'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tSPS＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '343,573',
#   '381,840',
#   '375,525',
#   '424,681',
#   '514,653',
#   '554,958',
#   '\xa0',
#   '\xa0'],
#  ['\n\n펼치기\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tEV/EBITDA\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '12.37',
#   '11.75',
#   '16.57',
#   '11.37',
#   '7.96',
#   '7.79',
#   '-30.00',
#   '-2.08'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tEV＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '765,044.6',
#   '873,635.9',
#   '1,090,036.7',
#   '1,277,281.6',
#   '1,183,246.9',
#   '1,285,322.1',
#   '\xa0',
#   '\xa0'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tEBITDA＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '61,836.3',
#   '74,373.8',
#   '65,800.4',
#   '112,346.9',
#   '148,673.9',
#   '164,923.4',
#   '\xa0',
#   '\xa0'],
#  ['\n\n펼치기\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tDPS\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '4,000',
#   '4,000',
#   '3,000',
#   '5,000',
#   '7,000',
#   '',
#   '40',
#   '\xa0'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t현금DPS\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '4,000',
#   '4,000',
#   '3,000',
#   '5,000',
#   '7,000',
#   '',
#   '\xa0',
#   '\xa0'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t주식DPS\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '0',
#   '0',
#   '0',
#   '0',
#   '',
#   '',
#   '\xa0',
#   '\xa0'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t현금배당수익률\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '3.38',
#   '3.32',
#   '1.56',
#   '2.39',
#   '4.64',
#   '3.74',
#   '2.24',
#   '-0.90'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t현금배당성향(%)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '70.70',
#   '35.35',
#   '55.15',
#   '26.32',
#   '24.85',
#   '16.78',
#   '-1.46',
#   '-8.07']]

# %%
col = []
for i in col_list :
    result = i.replace("\n", "")
    result = result.replace("연간컨센서스보기", "").replace("연간컨센서스닫기", "")
    col.append(result.strip())

col
# Out:
# ['항목',
#  '2018/12(IFRS연결)',
#  '2019/12(IFRS연결)',
#  '2020/12(IFRS연결)',
#  '2021/12(IFRS연결)',
#  '2022/12(IFRS연결)',
#  '2023/12(E)(IFRS연결)',
#  '전년대비(YoY)',
#  '전년대비(YoY)']

# %%
import pandas as pd

# %%
df = pd.DataFrame(value_list, columns = col)

# %%
def change(x) : 
    result = x.replace("\n", "")
    result = result.replace("\t", "")
    result = result.replace("펼치기", "")
    return result

df["항목"] = df["항목"].apply(change)

# %%
df.head(1)
# Out:
#     항목 2018/12(IFRS연결) 2019/12(IFRS연결) 2020/12(IFRS연결) 2021/12(IFRS연결)  \
# 0  EPS           5,352          10,761           5,143          17,846
#
#   2022/12(IFRS연결) 2023/12(E)(IFRS연결) 전년대비(YoY) 전년대비(YoY)
# 0          26,592             32,840        49        24

# %%
df.columns
# Out:
# Index(['항목', '2018/12(IFRS연결)', '2019/12(IFRS연결)', '2020/12(IFRS연결)',
#        '2021/12(IFRS연결)', '2022/12(IFRS연결)', '2023/12(E)(IFRS연결)', '전년대비(YoY)',
#        '전년대비(YoY)'],
#       dtype='object')

# %%
df.columns = ['항목', '2018/12(IFRS연결)', '2019/12(IFRS연결)', '2020/12(IFRS연결)',
       '2021/12(IFRS연결)', '2022/12(IFRS연결)', '2023/12(E)(IFRS연결)', '전년대비(2022)', '전년대비(2023)']

# %%
from datetime import datetime

# %%
now = datetime.now()
now = now.strftime("%Y%m%d%H%M%S")
now
# Out:
# '20230419101520'

# %%
df.to_csv(f"test({now}).csv", index = False)

# %%
pd.read_csv(f"test({now}).csv")
# Out:
#                           항목 2018/12(IFRS연결) 2019/12(IFRS연결) 2020/12(IFRS연결)  \
# 0                        EPS           5,352          10,761           5,143
# 1              당기순이익(지배)＜당기＞        15,080.8        29,800.5        14,244.4
# 2           보통주수정평균발행주식수＜당기＞     217,415,903     213,668,187     213,668,187
# 3           우선주수정평균발행주식수＜당기＞      64,366,142      63,270,871      63,270,871
# 4                        BPS         256,422         267,549         266,968
# 5               자본총계(지배)＜당기＞       679,739.7       700,658.0       694,806.3
# 6    보통주수정기말발행주식수(자사주차감)＜당기＞     204,280,606     201,833,036     200,576,769
# 7    우선주수정기말발행주식수(자사주차감)＜당기＞      60,805,434      60,047,227      59,681,734
# 8                        CPS          13,359           1,516          -1,480
# 9               영업활동현금흐름＜당기＞        37,642.7         4,197.8        -4,098.1
# 10          보통주수정평균발행주식수＜당기＞     217,415,903     213,668,187     213,668,187
# 11          우선주수정평균발행주식수＜당기＞      64,366,142      63,270,871      63,270,871
# 12                       SPS         343,573         381,840         375,525
# 13                   매출액＜당기＞       968,126.1     1,057,464.2     1,039,976.0
# 14          보통주수정평균발행주식수＜당기＞     217,415,903     213,668,187     213,668,187
# 15          우선주수정평균발행주식수＜당기＞      64,366,142      63,270,871      63,270,871
# 16                       PER           22.14           11.20           37.33
# 17           보통주수정주가(기말)＜당기＞         118,500         120,500         192,000
# 18                   EPS＜당기＞           5,352          10,761           5,143
# 19                       PBR            0.46            0.45            0.72
# 20           보통주수정주가(기말)＜당기＞         118,500         120,500         192,000
# 21                   BPS＜당기＞         256,422         267,549         266,968
# 22                       PCR            8.87           79.50         -129.75
# 23           보통주수정주가(기말)＜당기＞         118,500         120,500         192,000
# 24                   CPS＜당기＞          13,359           1,516          -1,480
# 25                       PSR            0.34            0.32            0.51
# 26           보통주수정주가(기말)＜당기＞         118,500         120,500         192,000
# 27                   SPS＜당기＞         343,573         381,840         375,525
# 28                 EV/EBITDA           12.37           11.75           16.57
# 29                    EV＜당기＞       765,044.6       873,635.9     1,090,036.7
# 30                EBITDA＜당기＞        61,836.3        74,373.8        65,800.4
# 31                       DPS           4,000           4,000           3,000
# 32                     현금DPS           4,000           4,000           3,000
# 33                     주식DPS               0               0               0
# 34                   현금배당수익률            3.38            3.32            1.56
# 35                 현금배당성향(%)           70.70           35.35           55.15
#
#    2021/12(IFRS연결) 2022/12(IFRS연결) 2023/12(E)(IFRS연결) 전년대비(2022) 전년대비(2023)
# 0           17,846          26,592             32,840         49         24
# 1         49,423.6        73,643.6           90,120.9
# 2      213,668,187     213,668,187        211,724,685
# 3       63,270,871      63,270,871         62,695,368
# 4          289,609         315,142            345,387          9         10
# 5        749,861.2       823,492.9          904,637.8
# 6      199,619,945     202,259,476        202,870,846
# 7       59,302,110      59,049,027         59,049,027
# 8           -4,248          38,374             54,071      1,003         41
# 9        -11,764.2       106,273.1          140,233.2
# 10     213,668,187     213,668,187        211,724,685
# 11      63,270,871      63,270,871         62,695,368
# 12         424,681         514,653            554,958         21          8
# 13     1,176,106.3     1,425,275.4        1,522,915.8
# 14     213,668,187     213,668,187        211,724,685
# 15      63,270,871      63,270,871         62,695,368
# 16           11.71            5.68               5.83     -51.51       2.64
# 17         209,000         151,000            191,400
# 18          17,846          26,592             32,840
# 19            0.72            0.48               0.55     -33.60      15.65
# 20         209,000         151,000            191,400
# 21         289,609         315,142            345,387
# 22          -49.20            3.93               3.54     108.00     -10.04
# 23         209,000         151,000            191,400
# 24          -4,248          38,374             54,071
# 25            0.49            0.29               0.34     -40.38      17.55
# 26         209,000         151,000            191,400
# 27         424,681         514,653            554,958
# 28           11.37            7.96               7.79     -30.00      -2.08
# 29     1,277,281.6     1,183,246.9        1,285,322.1
# 30       112,346.9       148,673.9          164,923.4
# 31           5,000           7,000                NaN         40
# 32           5,000           7,000                NaN
# 33               0             NaN                NaN
# 34            2.39            4.64               3.74       2.24      -0.90
# 35           26.32           24.85              16.78      -1.46      -8.07
