# %%
import pandas as pd

# %%
kospi1 = pd.read_csv("./코스피데이터(연결재무제표).csv", encoding = "euc-kr")
kospi1
# Out:
#            회사명  거래소코드     회계년도  매출액증가율(IFRS연결)  총자본증가율(IFRS연결)  \
# 0     (주)DB하이텍    990  2018/12           -1.54            7.30
# 1     (주)DB하이텍    990  2019/12           20.64            2.10
# 2     (주)DB하이텍    990  2020/12           15.92            8.24
# 3     (주)DB하이텍    990  2021/12           29.78           31.51
# 4     (주)DB하이텍    990  2022/12           37.92           36.95
# ...        ...    ...      ...             ...             ...
# 3688   흥아해운(주)   3280  2018/12           -9.87           -5.33
# 3689   흥아해운(주)   3280  2019/12          -86.45          -46.38
# 3690   흥아해운(주)   3280  2020/12          -12.95          -33.46
# 3691   흥아해운(주)   3280  2021/12           -8.11          -13.77
# 3692   흥아해운(주)   3280  2022/12          117.63           28.21
#
#       자기자본증가율(IFRS연결)  순이익증가율(IFRS연결)  유형자산증가율(IFRS연결)  비유동자산증가율(IFRS연결)  \
# 0               22.51          -21.19             7.56              6.69
# 1               15.45           20.51             3.18             -3.00
# 2               23.26           58.67             9.42              8.56
# 3               39.20           90.87            -2.50              2.14
# 4               48.12           76.35            12.18              8.19
# ...               ...             ...              ...               ...
# 3688           -37.42            0.00           -12.07             -5.17
# 3689           -57.73            0.00           -51.51            -51.51
# 3690          -185.01            0.00           -24.76            -32.47
# 3691             0.00            0.00           -20.91            -15.66
# 3692            26.95           37.95            16.81             10.41
#
#       유동자산증가율(IFRS연결)  ...  총자본투자효율(IFRS연결)  설비투자효율(IFRS연결)  기계투자효율(IFRS연결)  \
# 0                8.40  ...            28.98           61.13    1.409500e+02
# 1               11.19  ...            34.83           67.30    1.352100e+02
# 2                7.73  ...            41.06           83.62    1.773200e+02
# 3               77.51  ...            48.06          134.52    2.847200e+02
# 4               62.88  ...            50.35          189.56    3.855200e+02
# ...               ...  ...              ...             ...             ...
# 3688            -6.33  ...             4.24            6.91    1.135163e+09
# 3689           -13.42  ...             3.10            5.59    4.455416e+08
# 3690           -37.01  ...            -0.39           -0.62    0.000000e+00
# 3691            -6.48  ...            22.88           39.81    0.000000e+00
# 3692            90.07  ...            21.56           41.26    0.000000e+00
#
#       부가가치율(IFRS연결)  노동소득분배율(IFRS연결)  자본분배율(IFRS연결)  이윤분배율(IFRS연결)  상장폐지일  \
# 0             46.18            42.92          57.08          28.09    NaN
# 1             46.97            38.21          61.79          27.59    NaN
# 2             51.71            32.58          67.42          34.31    NaN
# 3             61.33            24.03          75.97          42.54    NaN
# 4             63.80            20.01          79.99          52.29    NaN
# ...             ...              ...            ...            ...    ...
# 3688           4.52           201.90        -101.90        -254.12    NaN
# 3689          13.08           241.39        -141.39        -384.23    NaN
# 3690          -1.25             0.00           0.00           0.00    NaN
# 3691          69.25            41.38          58.62          29.04    NaN
# 3692          38.43            50.36          49.64          34.84    NaN
#
#       소속코드         상장일
# 0        1  1975/12/12
# 1        1  1975/12/12
# 2        1  1975/12/12
# 3        1  1975/12/12
# 4        1  1975/12/12
# ...    ...         ...
# 3688     1  1976/06/29
# 3689     1  1976/06/29
# 3690     1  1976/06/29
# 3691     1  1976/06/29
# 3692     1  1976/06/29
#
# [3693 rows x 53 columns]

# %%
kospi2 = pd.read_csv("./코스피데이터(개별재무제표).csv", encoding = "euc-kr")
kospi2
# Out:
#            회사명  거래소코드     회계년도  매출액증가율(IFRS)  총자본증가율(IFRS)  자기자본증가율(IFRS)  \
# 0     (주)DB하이텍    990  2018/12         -1.54          7.48          22.88
# 1     (주)DB하이텍    990  2019/12         20.64          3.68          18.94
# 2     (주)DB하이텍    990  2020/12         15.92          8.25          23.23
# 3     (주)DB하이텍    990  2021/12         29.78         31.29          39.07
# 4     (주)DB하이텍    990  2022/12         37.92         36.93          48.04
# ...        ...    ...      ...           ...           ...            ...
# 3688   흥아해운(주)   3280  2018/12         -9.71         -6.15         -47.28
# 3689   흥아해운(주)   3280  2019/12        -86.19        -50.62         -68.92
# 3690   흥아해운(주)   3280  2020/12        -12.24        -26.33           0.00
# 3691   흥아해운(주)   3280  2021/12         -4.37        -12.91           0.00
# 3692   흥아해운(주)   3280  2022/12         78.69         18.15          18.38
#
#       순이익증가율(IFRS)  유형자산증가율(IFRS)  비유동자산증가율(IFRS)  유동자산증가율(IFRS)  ...  \
# 0            27.80           7.56            6.60           9.06  ...
# 1            27.42           3.18           -0.56          11.16  ...
# 2            36.73           9.43            8.51           7.84  ...
# 3            91.31          -2.50            2.12          77.60  ...
# 4            76.24          12.18            8.09          63.27  ...
# ...            ...            ...             ...            ...  ...
# 3688          0.00         -12.08           -6.68          -2.49  ...
# 3689          0.00         -51.49          -52.12         -40.70  ...
# 3690          0.00         -24.53          -28.24         -16.19  ...
# 3691          0.00         -20.80          -16.78           4.68  ...
# 3692        -11.60          15.59           12.07          40.17  ...
#
#       총자본투자효율(IFRS)  설비투자효율(IFRS)  기계투자효율(IFRS)  부가가치율(IFRS)  노동소득분배율(IFRS)  \
# 0             30.13         62.61        144.35        47.30          41.66
# 1             36.23         70.05        140.74        48.89          36.44
# 2             40.92         83.37        176.79        51.55          32.44
# 3             48.06        134.36        284.40        61.26          23.93
# 4             50.36        189.37        385.13        63.73          19.92
# ...             ...           ...           ...          ...            ...
# 3688           0.25          0.39          0.00         0.27        2884.67
# 3689           0.87          1.41          0.00         3.45         711.60
# 3690           4.21          6.68          0.00        14.03         168.69
# 3691          19.97         34.84          0.00        60.60          40.95
# 3692          18.56         33.20          0.00        37.25          48.67
#
#       자본분배율(IFRS)  이윤분배율(IFRS)  상장폐지일  소속코드         상장일
# 0           58.34        30.04    NaN     1  1975/12/12
# 1           63.56        30.70    NaN     1  1975/12/12
# 2           67.56        34.33    NaN     1  1975/12/12
# 3           76.07        42.59    NaN     1  1975/12/12
# 4           80.08        52.31    NaN     1  1975/12/12
# ...           ...          ...    ...   ...         ...
# 3688     -2784.67     -5047.86    NaN     1  1976/06/29
# 3689      -611.60     -1562.44    NaN     1  1976/06/29
# 3690       -68.69      -311.85    NaN     1  1976/06/29
# 3691        59.05        31.85    NaN     1  1976/06/29
# 3692        51.33        25.63    NaN     1  1976/06/29
#
# [3693 rows x 53 columns]

# %%
kosdaq1 = pd.read_csv("./코스닥데이터(연결재무제표).csv", encoding = "euc-kr")
kosdaq2 = pd.read_csv("./코스닥데이터(개별재무제표).csv", encoding = "euc-kr")

# %%
# csv 파일로부터 재무제표 데이터를 불러옴
kosdaq1 = pd.read_csv("./코스닥데이터(연결재무제표).csv", encoding = "euc-kr")
kosdaq2 = pd.read_csv("./코스닥데이터(개별재무제표).csv", encoding = "euc-kr")

# %%
# 결측치를 개별재무제표로 대체함
kosdaq = kosdaq1.fillna(kosdaq2)

# %%
kosdaq
# Out:
#            회사명  거래소코드     회계년도  매출액증가율(IFRS연결)  총자본증가율(IFRS연결)  \
# 0     (주)CMG제약  58820  2018/12           20.05            4.39
# 1     (주)CMG제약  58820  2019/12           17.56           68.07
# 2     (주)CMG제약  58820  2020/12             NaN             NaN
# 3     (주)CMG제약  58820  2021/12             NaN             NaN
# 4     (주)CMG제약  58820  2022/12             NaN             NaN
# ...        ...    ...      ...             ...             ...
# 7653   흥구석유(주)  24060  2018/12             NaN             NaN
# 7654   흥구석유(주)  24060  2019/12             NaN             NaN
# 7655   흥구석유(주)  24060  2020/12             NaN             NaN
# 7656   흥구석유(주)  24060  2021/12             NaN             NaN
# 7657   흥구석유(주)  24060  2022/12             NaN             NaN
#
#       자기자본증가율(IFRS연결)  순이익증가율(IFRS연결)  유형자산증가율(IFRS연결)  비유동자산증가율(IFRS연결)  \
# 0                6.16          113.94             6.71             16.47
# 1               73.26          -49.69            39.67             26.20
# 2                 NaN             NaN              NaN               NaN
# 3                 NaN             NaN              NaN               NaN
# 4                 NaN             NaN              NaN               NaN
# ...               ...             ...              ...               ...
# 7653              NaN             NaN              NaN               NaN
# 7654              NaN             NaN              NaN               NaN
# 7655              NaN             NaN              NaN               NaN
# 7656              NaN             NaN              NaN               NaN
# 7657              NaN             NaN              NaN               NaN
#
#       유동자산증가율(IFRS연결)  ...  총자본투자효율(IFRS연결)  설비투자효율(IFRS연결)  기계투자효율(IFRS연결)  \
# 0                0.18  ...            14.73          106.25          478.91
# 1               85.06  ...             9.90          114.60          438.05
# 2                 NaN  ...              NaN             NaN             NaN
# 3                 NaN  ...              NaN             NaN             NaN
# 4                 NaN  ...              NaN             NaN             NaN
# ...               ...  ...              ...             ...             ...
# 7653              NaN  ...              NaN             NaN             NaN
# 7654              NaN  ...              NaN             NaN             NaN
# 7655              NaN  ...              NaN             NaN             NaN
# 7656              NaN  ...              NaN             NaN             NaN
# 7657              NaN  ...              NaN             NaN             NaN
#
#       부가가치율(IFRS연결)  노동소득분배율(IFRS연결)  자본분배율(IFRS연결)  이윤분배율(IFRS연결)  상장폐지일  \
# 0             33.79            67.33          32.67          36.00    NaN
# 1             32.47            72.60          27.40          16.03    NaN
# 2               NaN              NaN            NaN            NaN    NaN
# 3               NaN              NaN            NaN            NaN    NaN
# 4               NaN              NaN            NaN            NaN    NaN
# ...             ...              ...            ...            ...    ...
# 7653            NaN              NaN            NaN            NaN    NaN
# 7654            NaN              NaN            NaN            NaN    NaN
# 7655            NaN              NaN            NaN            NaN    NaN
# 7656            NaN              NaN            NaN            NaN    NaN
# 7657            NaN              NaN            NaN            NaN    NaN
#
#       소속코드         상장일
# 0        5  2001/08/31
# 1        5  2001/08/31
# 2        5  2001/08/31
# 3        5  2001/08/31
# 4        5  2001/08/31
# ...    ...         ...
# 7653     5  1994/12/07
# 7654     5  1994/12/07
# 7655     5  1994/12/07
# 7656     5  1994/12/07
# 7657     5  1994/12/07
#
# [7658 rows x 53 columns]

# %%
# 대체된 데이터를 csv 파일로 저장함
kosdaq.to_csv('대체된코스닥연결재무제표.csv')
