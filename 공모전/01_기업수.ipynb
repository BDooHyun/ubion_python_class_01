# %%
import pandas as pd

# %%
kospi_in = pd.read_csv("../공모전/KOSPI(상장폐지포함).csv", encoding = "euc-kr")
kospi_in.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3692 entries, 0 to 3691
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   회사명              3692 non-null   object
#  1   거래소코드            3692 non-null   int64
#  2   회계년도             3692 non-null   object
#  3   매출액증가율(IFRS연결)   3141 non-null   float64
#  4   자기자본증가율(IFRS연결)  3141 non-null   float64
#  5   순이익증가율(IFRS연결)   3141 non-null   float64
#  6   총자본증가율(IFRS연결)   3141 non-null   float64
#  7   매출액순이익률(IFRS연결)  3141 non-null   float64
#  8   부채비율(IFRS연결)     3141 non-null   float64
#  9   총자본순이익률(IFRS연결)  3141 non-null   float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 288.6+ KB

# %%
kospi_out = pd.read_csv("../공모전/KOSPI(상장폐지미포함).csv", encoding = "euc-kr")
kospi_out.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3653 entries, 0 to 3652
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   회사명              3653 non-null   object
#  1   거래소코드            3653 non-null   int64
#  2   회계년도             3653 non-null   object
#  3   매출액증가율(IFRS연결)   3119 non-null   float64
#  4   자기자본증가율(IFRS연결)  3119 non-null   float64
#  5   순이익증가율(IFRS연결)   3119 non-null   float64
#  6   총자본증가율(IFRS연결)   3119 non-null   float64
#  7   매출액순이익률(IFRS연결)  3119 non-null   float64
#  8   부채비율(IFRS연결)     3119 non-null   float64
#  9   총자본순이익률(IFRS연결)  3119 non-null   float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 285.5+ KB

# %%
kosdaq_in = pd.read_csv("../공모전/KOSDAQ(상장폐지포함).csv", encoding = "euc-kr")
kosdaq_in.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7653 entries, 0 to 7652
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   회사명              7653 non-null   object
#  1   거래소코드            7653 non-null   int64
#  2   회계년도             7653 non-null   object
#  3   매출액증가율(IFRS연결)   5667 non-null   float64
#  4   자기자본증가율(IFRS연결)  5667 non-null   float64
#  5   순이익증가율(IFRS연결)   5667 non-null   float64
#  6   총자본증가율(IFRS연결)   5667 non-null   float64
#  7   매출액순이익률(IFRS연결)  5667 non-null   float64
#  8   부채비율(IFRS연결)     5667 non-null   float64
#  9   총자본순이익률(IFRS연결)  5667 non-null   float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 598.0+ KB

# %%
df = kosdaq_in["회사명"].unique()

# %%
pd.Series(df).value_counts()
# Out:
# (주)CMG제약          1
# (주)프럼파스트          1
# (주)플레이디           1
# (주)플랜티넷           1
# (주)플래티어           1
#                  ..
# (주)에스엠코어          1
# (주)에스엠컬처앤콘텐츠      1
# (주)에스엠엔터테인먼트      1
# (주)에스엠라이프디자인그룹    1
# 흥구석유(주)           1
# Length: 1605, dtype: int64

# %%
kosdaq_in.head() 매출액증가율,자기자본증가율,순이익증가율,총자본증가율,매출액순이익률,부채비율,총자본순이익률
# Out:
#         회사명  거래소코드     회계년도  매출액증가율(IFRS연결)  자기자본증가율(IFRS연결)  순이익증가율(IFRS연결)  \
# 0  (주)CMG제약  58820  2018/12           20.05             6.16          113.94
# 1  (주)CMG제약  58820  2019/12           17.56            73.26          -49.69
# 2  (주)CMG제약  58820  2020/12             NaN              NaN             NaN
# 3  (주)CMG제약  58820  2021/12             NaN              NaN             NaN
# 4  (주)CMG제약  58820  2022/12             NaN              NaN             NaN
#
#    총자본증가율(IFRS연결)  매출액순이익률(IFRS연결)  부채비율(IFRS연결)  총자본순이익률(IFRS연결)
# 0            4.39            12.16         10.00             5.42
# 1           68.07             5.20          6.71             1.99
# 2             NaN              NaN           NaN              NaN
# 3             NaN              NaN           NaN              NaN
# 4             NaN              NaN           NaN              NaN

# %%
len(kospi_out["거래소코드"].unique())
# Out:
# 737

# %%
len(kospi_out["회사명"].unique())
# Out:
# 737

# %%
kospi_in
# Out:
#            회사명  거래소코드     회계년도  매출액증가율(IFRS연결)  자기자본증가율(IFRS연결)  \
# 0     (주)DB하이텍    990  2018/12           -1.54            22.51
# 1     (주)DB하이텍    990  2019/12           20.64            15.45
# 2     (주)DB하이텍    990  2020/12           15.92            23.26
# 3     (주)DB하이텍    990  2021/12           29.78            39.20
# 4     (주)DB하이텍    990  2022/12           37.92            48.12
# ...        ...    ...      ...             ...              ...
# 3687   흥아해운(주)   3280  2018/12           -9.87           -37.42
# 3688   흥아해운(주)   3280  2019/12          -86.45           -57.73
# 3689   흥아해운(주)   3280  2020/12          -12.95          -185.01
# 3690   흥아해운(주)   3280  2021/12           -8.11             0.00
# 3691   흥아해운(주)   3280  2022/12          117.63            26.95
#
#       순이익증가율(IFRS연결)  총자본증가율(IFRS연결)  매출액순이익률(IFRS연결)  부채비율(IFRS연결)  \
# 0             -21.19            7.30            12.97         91.00
# ...

# %%
kospi = pd.read_csv("코스피.csv", encoding = "euc-kr")

# %%
# 코스피 상장폐지 종목
kospi_sp = kospi[~kospi["상장폐지일"].isnull()].reset_index(drop = True)
len(kospi_sp["회사명"].unique())
# Out:
# 16

# %%
kospi
# Out:
#            회사명  거래소코드     회계년도 상장폐지일  소속코드         상장일  매출액증가율(IFRS)  \
# 0     (주)DB하이텍    990  2018/12   NaN     1  1975/12/12         -1.54
# 1     (주)DB하이텍    990  2019/12   NaN     1  1975/12/12         20.64
# 2     (주)DB하이텍    990  2020/12   NaN     1  1975/12/12         15.92
# 3     (주)DB하이텍    990  2021/12   NaN     1  1975/12/12         29.78
# 4     (주)DB하이텍    990  2022/12   NaN     1  1975/12/12         37.92
# ...        ...    ...      ...   ...   ...         ...           ...
# 3687   흥아해운(주)   3280  2018/12   NaN     1  1976/06/29         -9.71
# 3688   흥아해운(주)   3280  2019/12   NaN     1  1976/06/29        -86.19
# 3689   흥아해운(주)   3280  2020/12   NaN     1  1976/06/29        -12.24
# 3690   흥아해운(주)   3280  2021/12   NaN     1  1976/06/29         -4.37
# 3691   흥아해운(주)   3280  2022/12   NaN     1  1976/06/29         78.69
#
#       자기자본증가율(IFRS)  순이익증가율(IFRS)  총자본증가율(IFRS)  매출액순이익률(IFRS)  부채비율(IFRS)  \
# ...

# %%
kosdaq = pd.read_csv("코스닥.csv", encoding = "euc-kr")
kosdaq
# Out:
#            회사명  거래소코드     회계년도 상장폐지일  소속코드         상장일  매출액증가율(IFRS)  \
# 0     (주)CMG제약  58820  2018/12   NaN     5  2001/08/31         20.05
# 1     (주)CMG제약  58820  2019/12   NaN     5  2001/08/31         17.56
# 2     (주)CMG제약  58820  2020/12   NaN     5  2001/08/31          9.96
# 3     (주)CMG제약  58820  2021/12   NaN     5  2001/08/31          7.78
# 4     (주)CMG제약  58820  2022/12   NaN     5  2001/08/31         18.31
# ...        ...    ...      ...   ...   ...         ...           ...
# 7648   흥구석유(주)  24060  2018/12   NaN     5  1994/12/07          6.87
# 7649   흥구석유(주)  24060  2019/12   NaN     5  1994/12/07         -9.35
# 7650   흥구석유(주)  24060  2020/12   NaN     5  1994/12/07        -23.78
# 7651   흥구석유(주)  24060  2021/12   NaN     5  1994/12/07         15.12
# 7652   흥구석유(주)  24060  2022/12   NaN     5  1994/12/07         10.97
#
#       자기자본증가율(IFRS)  순이익증가율(IFRS)  총자본증가율(IFRS)  매출액순이익률(IFRS)  부채비율(IFRS)  \
# ...

# %%
kosdaq_sp = kosdaq[~kosdaq["상장폐지일"].isnull()].reset_index(drop = True)
kosdaq_sp
# Out:
#            회사명   거래소코드     회계년도       상장폐지일  소속코드         상장일  매출액증가율(IFRS)  \
# 0      (주)구스앤홈  329050  2018/12  2021/04/13     4  2019/07/12           NaN
# 1      (주)구스앤홈  329050  2019/12  2021/04/13     4  2019/07/12           NaN
# 2      (주)구스앤홈  329050  2020/12  2021/04/13     4  2019/07/12           NaN
# 3        (주)금빛   45890  2018/12  2021/12/20     4  2005/11/28        -23.42
# 4        (주)금빛   45890  2019/12  2021/12/20     4  2005/11/28          9.61
# ..         ...     ...      ...         ...   ...         ...           ...
# 265  현대정보기술(주)   26180  2018/12  2019/07/17     4  2000/08/08         -4.46
# 266    현진소재(주)   53660  2018/12  2022/04/26     4  2002/02/15        -12.01
# 267    현진소재(주)   53660  2019/12  2022/04/26     4  2002/02/15        -14.08
# 268    현진소재(주)   53660  2020/12  2022/04/26     4  2002/02/15        -87.18
# 269    현진소재(주)   53660  2021/12  2022/04/26     4  2002/02/15         -1.01
#
# ...

# %%
len(kosdaq_sp["회사명"].unique())
# Out:
# 109
