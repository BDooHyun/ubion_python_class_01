# %%
import pandas as pd

# %%
df = pd.read_csv('./datasets/코스피시가총액.csv', encoding="EUC-KR")

# %%
df.sort_values(by="시가총액", ascending=False, ignore_index=True, inplace=True)

# %%
df_big = df.iloc[:100]
df_mid = df.iloc[100:300]
df_sml = df.iloc[300:]

# %%
df_big.head(30)
# Out:
#       종목코드       종목명   시장구분    업종명      종가     대비   등락률             시가총액
# 0   005930      삼성전자  KOSPI   전기전자   72600    200  0.28  433406213130000
# 1   373220  LG에너지솔루션  KOSPI   전기전자  561000  -3000 -0.53  131274000000000
# 2   000660    SK하이닉스  KOSPI   전기전자  113000   -500 -0.44   82264267245000
# 3   207940  삼성바이오로직스  KOSPI    의약품  748000 -12000 -1.58   53238152000000
# 4   051910      LG화학  KOSPI     화학  703000      0  0.00   49626417129000
# 5   005935     삼성전자우  KOSPI   전기전자   60300   -200 -0.33   49620068010000
# 6   006400     삼성SDI  KOSPI   전기전자  678000  -5000 -0.73   46622351340000
# 7   005380       현대차  KOSPI   운수장비  206000   5500  2.74   43575490236000
# 8   000270        기아  KOSPI   운수장비   86200    700  0.82   34656210298600
# 9   005490  POSCO홀딩스  KOSPI   철강금속  403500   3500  0.88   34124491305000
# 10  035420     NAVER  KOSPI   서비스업  185900  -3000 -1.59   30496724901500
# 11  003670    포스코퓨처엠  KOSPI   전기전자  365000  -9000 -2.41   28274075300000
# ...
