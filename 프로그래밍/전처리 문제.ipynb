# %% [markdown]
# ### 공기의 질을 측정한 데이터
# 1. airquanlity 데이터에 대해서 결측치가 가장 많은 변수를 찾아서 해당 결측치를 0으로 대체하고 결측치를 제외한 평균과 0으로 대치한 후 평균의 차이를 구하시오
# 2. wind 변수에 대해서 Min-Max 정규화를 수행 한 후 평균 값과 Z 정규화를 수행 한 후 평균 값의 차이를 구하시오
# 3. 월별 평균 기온을 구하시오

# %%
import pandas as pd
df = pd.read_csv("./1일차_data./airquality.csv")
df_1 = pd.read_csv("./1일차_data./airquality.csv")
df
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day
# 0     41.0    190.0   7.4    67      5    1
# 1     36.0    118.0   8.0    72      5    2
# 2     12.0    149.0  12.6    74      5    3
# 3     18.0    313.0  11.5    62      5    4
# 4      NaN      NaN  14.3    56      5    5
# ..     ...      ...   ...   ...    ...  ...
# 148   30.0    193.0   6.9    70      9   26
# 149    NaN    145.0  13.2    77      9   27
# 150   14.0    191.0  14.3    75      9   28
# 151   18.0    131.0   8.0    76      9   29
# 152   20.0    223.0  11.5    68      9   30
#
# [153 rows x 6 columns]

# %%
df.isna().sum()
# Out:
# Ozone      37
# Solar.R     7
# Wind        0
# Temp        0
# Month       0
# Day         0
# dtype: int64

# %%
df_1["Ozone"] = df_1["Ozone"].fillna(0)

# %%
df_1.isna().sum()
# Out:
# Ozone      0
# Solar.R    7
# Wind       0
# Temp       0
# Month      0
# Day        0
# dtype: int64

# %%
df.mean()
# Out:
# Ozone       42.129310
# Solar.R    185.931507
# Wind         9.957516
# Temp        77.882353
# Month        6.993464
# Day         15.803922
# dtype: float64

# %%
df_1.mean()
# Out:
# Ozone       31.941176
# Solar.R    185.931507
# Wind         9.957516
# Temp        77.882353
# Month        6.993464
# Day         15.803922
# dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler

MmScaler = MinMaxScaler()

MmScaler.fit(df[["Wind"]])
wind_mm = MmScaler.transform(df[["Wind"]])
wind_mm.mean()
# Out:
# 0.4346061231510147

# %%
from sklearn.preprocessing import StandardScaler

StdScaler = StandardScaler()

StdScaler.fit(df[["Wind"]])
wind_z = StdScaler.transform(df[["Wind"]])
wind_z.mean()
# Out:
# -2.322035084183334e-17

# %%
df["Temp"].groupby(df["Month"]).mean()
# Out:
# Month
# 5    65.548387
# 6    79.100000
# 7    83.903226
# 8    83.967742
# 9    76.900000
# Name: Temp, dtype: float64

# %% [markdown]
# ### 근무자 정보를 측정한 데이터
# 1. Attrition은 퇴사 여부 데이터를 (yes:1, no:0)으로 데이터를 변환하여 새로운 파생변수에 대입하고 범주별 레코드 수를 계산하시오
# 2. 범주형 변수 중 유일한 값을 1개만 가지고 있는 컬럼을 찾아내어 그 컬럼을 데이터에서 제거하시오
# 3. 원래 데이터에서 숫자형인 컬럼만 추출하여 새로운 데이터프레임으로 생성하고, 각 변수간의 상관계수(피어슨 상관계수)를 구하시오

# %%
at = pd.read_csv("./1일차_data./HR-Employee-Attrition.csv")
at
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department
# 0      41       Yes      Travel_Rarely       1102                   Sales  \
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount
# ...

# %%
at["퇴사여부"] = at["Attrition"].apply(lambda x: 1 if x == 'Yes' else 0)
at.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department
# 0   41       Yes      Travel_Rarely       1102                   Sales  \
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber
# 0                 1          2  Life Sciences              1               1  \
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  StandardHours StockOptionLevel  TotalWorkingYears
# ...

# %%
at["퇴사여부"].value_counts()
# Out:
# 퇴사여부
# 0    1233
# 1     237
# Name: count, dtype: int64

# %%
pd.get_dummies(at, columns=["퇴사여부"])
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department
# 0      41       Yes      Travel_Rarely       1102                   Sales  \
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount
# ...

# %%
num_at = at.select_dtypes(include='number')
num_at
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EmployeeCount
# 0      41       1102                 1          2              1  \
# 1      49        279                 8          1              1
# 2      37       1373                 2          2              1
# 3      33       1392                 3          4              1
# 4      27        591                 2          1              1
# ...   ...        ...               ...        ...            ...
# 1465   36        884                23          2              1
# 1466   39        613                 6          1              1
# 1467   27        155                 4          3              1
# 1468   49       1023                 2          3              1
# 1469   34        628                 8          3              1
#
#       EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement
# 0                  1                        2          94               3  \
# ...

# %%
num_at.corr(method='pearson')
# Out:
#                                Age  DailyRate  DistanceFromHome  Education
# Age                       1.000000   0.010661         -0.001686   0.208034  \
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...
