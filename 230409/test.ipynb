# %%
import pandas as pd

# %%
volume = pd.read_csv("../contest/howmany_20230409.csv", encoding = "euc-kr")

# %%
kospi = pd.read_csv("../contest/stock_20230409.csv")

# %%
volume.head()
# Out:
#            일자     기관 합계     기타법인        개인    외국인 합계  전체
# 0  2023/04/07   2635252  3614587 -17916452  11666613   0
# 1  2023/04/06 -10079237  1283451  22811840 -14016054   0
# 2  2023/04/05   1233022  1783587   9112053 -12128662   0
# 3  2023/04/04   4181441  1630574 -11470320   5658305   0
# 4  2023/04/03  -4814742   705086  -4889941   8999597   0

# %%
kospi.head()
# Out:
#            변환       원자료
# 0  2023/04/07  2,490.41
# 1  2023/04/06  2,459.23
# 2  2023/04/05  2,495.21
# 3  2023/04/04  2,480.51
# 4  2023/04/03  2,472.34

# %%
kospi.columns = ["일자", "코스피지수"]

# %%
kospi.head()
# Out:
#            일자     코스피지수
# 0  2023/04/07  2,490.41
# 1  2023/04/06  2,459.23
# 2  2023/04/05  2,495.21
# 3  2023/04/04  2,480.51
# 4  2023/04/03  2,472.34

# %%
df = pd.merge(volume, kospi, on = "일자", how = "inner")
df.head(1)
# Out:
#            일자    기관 합계     기타법인        개인    외국인 합계  전체     코스피지수
# 0  2023/04/07  2635252  3614587 -17916452  11666613   0  2,490.41

# %%
df.drop(["전체"], axis = 1, inplace = True)

# %%
df
# Out:
#             일자     기관 합계      기타법인        개인    외국인 합계     코스피지수
# 0   2023/04/07   2635252   3614587 -17916452  11666613  2,490.41
# 1   2023/04/06 -10079237   1283451  22811840 -14016054  2,459.23
# 2   2023/04/05   1233022   1783587   9112053 -12128662  2,495.21
# 3   2023/04/04   4181441   1630574 -11470320   5658305  2,480.51
# 4   2023/04/03  -4814742    705086  -4889941   8999597  2,472.34
# 5   2023/03/31 -16673083   1800635  16056988  -1184540  2,476.86
# 6   2023/03/30 -40791160  38944843  -8266939  10113256  2,453.16
# 7   2023/03/29   6303749     40042 -16075805   9732014  2,443.92
# 8   2023/03/28   7837516  -1826090 -20211307  14199881  2,434.94
# 9   2023/03/27    -49290   -607268     66539    590019  2,409.22
# 10  2023/03/24  -4379877  -6280805  -5270478  15931160  2,414.96
# 11  2023/03/23   3706668  -3558036   2835176  -2983808  2,424.48
# 12  2023/03/22    318592  -1868921   7782903  -6232574  2,416.96
# ...

# %%
a = 2635252	+ 3614587 + 11666613 + (-17916452)
print(a)
# Out:
# 0

# %%
b = 2,490.41 * 10000 / -17916452
print(b)
# Out:
# (2, -0.27372048885571765)

# %%
df["개인순매수비율"] = df["코스피지수"] * 10000 / df["개인"]
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\duja1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\ops\array_ops.py:165, in _na_arithmetic_op(left, right, op, is_cmp)
#     164 try:
# --> 165     result = func(left, right)
#     166 except TypeError:
#
# File c:\Users\duja1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\computation\expressions.py:241, in evaluate(op, a, b, use_numexpr)
#     239     if use_numexpr:
#     240         # error: "None" not callable
# --> 241         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     242 return _evaluate_standard(op, op_str, a, b)
#
# File c:\Users\duja1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\computation\expressions.py:70, in _evaluate_standard(op, op_str, a, b)
#      69     _store_test_result(False)
# ---> 70 return op(a, b)
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27 entries, 0 to 26
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   일자      27 non-null     object
#  1   기관 합계   27 non-null     int64
#  2   기타법인    27 non-null     int64
#  3   개인      27 non-null     int64
#  4   외국인 합계  27 non-null     int64
#  5   코스피지수   27 non-null     object
# dtypes: int64(4), object(2)
# memory usage: 1.5+ KB

# %%
import numpy as np

# %%
df["코스피지수"] = df['코스피지수'].str.replace(",", "").astype(float)

# %%
df.head()
# Out:
#            일자     기관 합계     기타법인        개인    외국인 합계    코스피지수
# 0  2023/04/07   2635252  3614587 -17916452  11666613  2490.41
# 1  2023/04/06 -10079237  1283451  22811840 -14016054  2459.23
# 2  2023/04/05   1233022  1783587   9112053 -12128662  2495.21
# 3  2023/04/04   4181441  1630574 -11470320   5658305  2480.51
# 4  2023/04/03  -4814742   705086  -4889941   8999597  2472.34

# %%
df["개인순매수비율"] = df["코스피지수"] * 10000 / df["개인"]

# %%
df
# Out:
#             일자     기관 합계      기타법인        개인    외국인 합계    코스피지수     개인순매수비율
# 0   2023/04/07   2635252   3614587 -17916452  11666613  2490.41   -1.390013
# 1   2023/04/06 -10079237   1283451  22811840 -14016054  2459.23    1.078050
# 2   2023/04/05   1233022   1783587   9112053 -12128662  2495.21    2.738362
# 3   2023/04/04   4181441   1630574 -11470320   5658305  2480.51   -2.162546
# 4   2023/04/03  -4814742    705086  -4889941   8999597  2472.34   -5.055971
# 5   2023/03/31 -16673083   1800635  16056988  -1184540  2476.86    1.542543
# 6   2023/03/30 -40791160  38944843  -8266939  10113256  2453.16   -2.967435
# 7   2023/03/29   6303749     40042 -16075805   9732014  2443.92   -1.520247
# 8   2023/03/28   7837516  -1826090 -20211307  14199881  2434.94   -1.204741
# 9   2023/03/27    -49290   -607268     66539    590019  2409.22  362.076376
# 10  2023/03/24  -4379877  -6280805  -5270478  15931160  2414.96   -4.582051
# ...
